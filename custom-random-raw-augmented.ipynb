# %% [markdown]
# # Combination: custom-random-raw-augmented
#
# Custom CNN
#
# Random split
#
# Raw images (no bounding box)
#
# Transformation with augmentation

# %%
import torch

import os

import paths

from sysinfo import get_device

from torchvision.datasets import ImageFolder

import transforms

from customcnn import make_model

from train import training_loop

from test_model import test_model

# %%
MODEL_ID = 'custom-random-raw-augmented'
TRAIN_DATA_PATH = paths.random_splits_train
TEST_DATA_PATH = paths.random_splits_test
TRANSFORM = transforms.get_augmented_transforms()
LOOPS=10 # Number of training loops to run, increased from 5 to 10 because of augmented data

# %%
SAVED_MODEL_PATH = os.path.join(paths.models, MODEL_ID + '.pth')

# %%
device = get_device()
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4
# GPU device: NVIDIA GeForce RTX 2060
# Using device: cuda

# %%
dataset = ImageFolder(TRAIN_DATA_PATH, transform=TRANSFORM)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8)

# %%
model = make_model(device)
# Out:
# c:\Users\lootman\anaconda3\envs\avpr\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\lootman\anaconda3\envs\avpr\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
if os.path.exists(SAVED_MODEL_PATH):
    model.load_state_dict(torch.load(SAVED_MODEL_PATH))
else:
    training_loop(LOOPS, model, data_loader, device)
    torch.save(model.state_dict(), SAVED_MODEL_PATH)
# Out:
# Epoch 1 completed. Loss: 3.7922730445861816
# Epoch 2 completed. Loss: 4.082004547119141
# Epoch 3 completed. Loss: 4.124275207519531
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2     model.load_state_dict(torch.load(SAVED_MODEL_PATH))
#       3 else:
# ----> 4     training_loop(LOOPS, model, data_loader, device)
#       5     torch.save(model.state_dict(), SAVED_MODEL_PATH)
#
# File g:\disks\YandexDisk\documents\Университет\AVPR\Assignment 2\train.py:9, in training_loop(num_epochs, model, train_loader, device)
#       6 criterion = nn.CrossEntropyLoss()
#       8 for epoch in range(num_epochs):
# ----> 9     train_loss = train_on_dataset(model, train_loader, optimizer, criterion, device)
#      10     print(f"Epoch {epoch + 1} completed. Loss: {train_loss.item()}")
#      12 print("Training complete.")
#
# File g:\disks\YandexDisk\documents\Университет\AVPR\Assignment 2\train.py:15, in train_on_dataset(model, dataloader, optimizer, criterion, device)
#      14 def train_on_dataset(model, dataloader, optimizer, criterion, device):
# ---> 15     for images, labels in dataloader:
#      16         images = images.to(device)
#      17         labels = labels.to(device)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\site-packages\torch\utils\data\dataloader.py:484, in DataLoader.__iter__(self)
#     482     return self._iterator
#     483 else:
# --> 484     return self._get_iterator()
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\site-packages\torch\utils\data\dataloader.py:415, in DataLoader._get_iterator(self)
#     413 else:
#     414     self.check_worker_number_rationality()
# --> 415     return _MultiProcessingDataLoaderIter(self)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\site-packages\torch\utils\data\dataloader.py:1138, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1131 w.daemon = True
#    1132 # NB: Process.start() actually take some time as it needs to
#    1133 #     start a process and pass the arguments over via a pipe.
#    1134 #     Therefore, we only add a worker to self._workers list after
#    1135 #     it started, so that we do not call .join() if program dies
#    1136 #     before it starts, and __del__ tries to join but will get:
#    1137 #     AssertionError: can only join a started process.
# -> 1138 w.start()
#    1139 self._index_queues.append(index_queue)
#    1140 self._workers.append(w)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\multiprocessing\popen_spawn_win32.py:95, in Popen.__init__(self, process_obj)
#      93 try:
#      94     reduction.dump(prep_data, to_child)
# ---> 95     reduction.dump(process_obj, to_child)
#      96 finally:
#      97     set_spawning_popen(None)
#
# File c:\Users\lootman\anaconda3\envs\avpr\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
test_dataset = ImageFolder(TEST_DATA_PATH, transform=TRANSFORM)
test_data_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=8)

# %%
correct, total, accuracy, all_labels, all_predictions = test_model(model, test_data_loader, device)
# Out:
# Accuracy of the model on the test images: 2.52%
